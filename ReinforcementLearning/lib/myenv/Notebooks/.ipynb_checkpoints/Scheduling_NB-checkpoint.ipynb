# %% [markdown]
# # Scheduling Environement with OpenAI Gym

# %% [markdown]
# ### Case 1: Uniskill Agents and Uniservice call center

# %%
import gymnasium as gym
import numpy as np
from gymnasium import spaces
import matplotlib.pyplot as plt
from datetime import datetime, timedelta
import random
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
from pyworkforce.queuing import ErlangC
import torch

# %%
def genArrivals():

        # Define arrival rate (e.g., 10 arrivals per hour)
        lambda_per_hour = 10

        # Define number of intervals in the day (48 intervals for 30-minute spacing over 24 hours)
        num_intervals = 48

        # Generate arrivals for each interval
        arrivals = np.random.poisson(lambda_per_hour / 2, num_intervals)

        # Generate time intervals
        time_intervals = pd.date_range(start="00:00:00", periods=num_intervals, freq="30T").time

        df=pd.DataFrame({'time':time_intervals,'arrivals':arrivals})

        df.to_csv("data/arrivals.csv")

def get_agents_schedule(shifts, shift_duration):
    # Convert shift duration to equivalent number of 30-min slots
    slots_for_shift = 2 * shift_duration

    # Initialize a dictionary
    agents_per_30mins_dict = {}

    # Function to convert index to HH:MM time format
    def index_to_time(index):
        hh = index // 2
        mm = (index % 2) * 30
        return f"{hh:02d}:{mm:02d}"

    # Function to convert HH:MM time to an index
    def time_to_index(time_str):
        hh, mm = map(int, time_str.split(":"))
        return 2 * hh + mm // 30

    # Ensure all time slots are present in the dict
    for i in range(48):
        time_key = index_to_time(i)
        agents_per_30mins_dict[time_key] = 0

    for count, time_str in shifts:
        start_index = time_to_index(time_str)
        for i in range(slots_for_shift):
            if start_index + i < 48:
                time_key = index_to_time(start_index + i)
                agents_per_30mins_dict[time_key] += count

    # Sort the dictionary by keys
    sorted_agents_dict = dict(sorted(agents_per_30mins_dict.items()))

    return sorted_agents_dict

# %%
def calculate_shift_extended(gk):
    # list of actions (number of agents, shift start time) for the whole episode
    shifts=gk

    # the duration of the shifts 
    shift_duration = 3 # 2 hours

    # this shows the number of agents for every 30 minutes
    shifts_extended = get_agents_schedule(shifts, shift_duration)
    return shifts_extended



def calculate_reward(gk,arrivals):
    """
    Calculate a service level reward. 

    Parameters:
    - gk (list): List of action (number of agents,start time) for an episode.
    - arrivals (list): List of of arrivals (calls volume for every 30 minutes).

    Returns:
    - The reward score.
    """
    
    shifts_extended=calculate_shift_extended(gk)
    
    # we calculate the service level (sl) for every 30 minutes then average them
    # sl is calculated using Erlang C by comparing the number of agents working and arrivals
    
    sl=[]
    for a,p in zip(list(arrivals.arrivals.values),list(shifts_extended.values())):

        if a>0 and p>0:
            erlang = ErlangC(transactions=a, asa=20/60, aht=2, interval=30, shrinkage=0)
            sl.append(erlang.service_level(positions=p))
    #         print("waiting probability",erlang.waiting_probability(positions=p))

        # the case where we have arrivals but no agents to handle them ---> sl==0
        if a>0 and p==0:
            sl.append(0)
            
    
    # Service Level: The expected percentage of transactions that don’t wait in the queue longer than the target ASA
    # Average speed of answer (ASA): Average time that a transaction waits in the queue to be attended by a resource
    # The requirement is fixed by the call center for service level is 80%
    # the reward score is arbitratry +30 and -30
    
    number_sl_violation=np.sum(np.array(sl)<0.80)
    number_sl_respected=np.sum(np.array(sl)>=0.80)
    
    reward=(number_sl_respected*30)+(number_sl_violation*-30)
            
            
    return reward

# %%
arrivals=pd.read_csv("../data/arrivals.csv")
arrivals.head()
# Out:
#    Unnamed: 0      time  arrivals
# 0           0  00:00:00         3
# 1           1  00:30:00         4
# 2           2  01:00:00         2
# 3           3  01:30:00        11
# 4           4  02:00:00        10

# %%
class scheduling(gym.Env):
    """ Scheduling Environment """

    

    def time_slots(self):
       # Define the start and end times for the day
        start_time = datetime.strptime("00:00", "%H:%M")
        end_time = datetime.strptime("23:59", "%H:%M")

        # Initialize a dictionary to store the index and time slot pairs
        time_slots_dict = {}

        # Generate time slots for every 30 minutes and store them with an index
        current_time = start_time
        index = 1
        while current_time <= end_time:
            time_slots_dict[index] = current_time.strftime("%H:%M")
            current_time += timedelta(minutes=30)
            index += 1

        # Example usage:
        # Print all index-time slot pairs
        # for index, time_slot in time_slots_dict.items():
        #     print(f"Index {index}: {time_slot}")

        return time_slots_dict


    def __init__(self,n_agents=11,n_services=1,n_shifts=4):
        super().__init__()

        # number of start time
        self.n_st=48
        # number of agents
        self.n_agents=n_agents
        #agent ids
        self.agents_ids=[i for i in range(1,self.n_agents)]

        # time slots
        self.ts=self.time_slots()
        # number of services
        self.n_services=n_services
        # number of shifts
        self.n_shifts=n_shifts

        # observation space
        self.observation_space = spaces.Discrete(n_services*n_shifts)
        self.observation_space=1
       
        # Action space 
        self.action_space = spaces.Tuple((
                    spaces.Discrete(self.n_agents),  # number of agents
                    spaces.Discrete(self.n_st),  # start time 
                
                ))
       
        # termination of episode condition
        self.terminated=False

        # list of action
        self.gk=[]


    def step(self, action,arrivals):
        if self.terminated==False:
            # substract the dispatched agents from the total number of available agents   
            self.n_agents-=action[0]
       
            

        print("number of available agents",self.n_agents)

        if self.observation_space!=self.n_shifts:
            reward=0
            self.gk.append(action)
            print("observation_space is:",self.observation_space)
            print("reward is:",reward)
            self.observation_space+=1

            return self.observation_space, reward, self.terminated
        
        else:
            self.gk.append(action)
            reward=calculate_reward(self.gk,arrivals)
            print("observation_space is:",self.observation_space)
            print("reward is:",reward)
            print("shifts: ",self.gk)
            self.terminated=True
            return self.observation_space, reward, self.terminated

           
    
    def reset(self, seed=None, options=None):
         self.observation_space=1
         

         self.terminated=False
    
    def render(self, V,mode='human'):
       pass

# %%
# looping over multiple episodes
reward_list=[]
for _ in range(100):
    s=scheduling(n_agents=11,n_services=1,n_shifts=4)
    # Loop over an episode of 5 shift 
    for _ in range(11):

        # pick random number of agent
        if s.n_agents!=0:
             n_ag = random.randint(1, s.n_agents)

        else:
            n_ag=0

        # picking actions randomly (start time, nb_agents) here we should use a policy !
        values = list(s.ts.values())
        random_ts = random.choice(values)

        # step using random action 
        o,reward,t=s.step(action=(n_ag,random_ts),arrivals=arrivals)
        
    reward_list.append(reward)
# Out:
# number of available agents 3
# observation_space is: 1
# reward is: 0
# number of available agents 2
# observation_space is: 2
# reward is: 0
# number of available agents 1
# observation_space is: 3
# reward is: 0
# number of available agents 0
# observation_space is: 4
# reward is: -660
# shifts:  [(8, '03:00'), (1, '09:00'), (1, '17:00'), (1, '01:00')]
# number of available agents 0
# observation_space is: 4
# reward is: -660
# shifts:  [(8, '03:00'), (1, '09:00'), (1, '17:00'), (1, '01:00'), (0, '19:00')]
# number of available agents 0
# observation_space is: 4
# reward is: -660
# shifts:  [(8, '03:00'), (1, '09:00'), (1, '17:00'), (1, '01:00'), (0, '19:00'), (0, '19:00')]
# number of available agents 0
# observation_space is: 4
# reward is: -660
# shifts:  [(8, '03:00'), (1, '09:00'), (1, '17:00'), (1, '01:00'), (0, '19:00'), (0, '19:00'), (0, '16:30')]
# number of available agents 0
# observation_space is: 4
# reward is: -660
# shifts:  [(8, '03:00'), (1, '09:00'), (1, '17:00'), (1, '01:00'), (0, '19:00'), (0, '19:00'), (0, '16:30'), (0, '17:30')]
# number of available agents 0
# observation_space is: 4
# reward is: -660
# shifts:  [(8, '03:00'), (1, '09:00'), (1, '17:00'), (1, '01:00'), (0, '19:00'), (0, '19:00'), (0, '16:30'), (0, '17:30'), (0, '20:00')]
# number of available agents 0
# observation_space is: 4
# reward is: -660
# shifts:  [(8, '03:00'), (1, '09:00'), (1, '17:00'), (1, '01:00'), (0, '19:00'), (0, '19:00'), (0, '16:30'), (0, '17:30'), (0, '20:00'), (0, '07:00')]
# number of available agents 0
# observation_space is: 4
# reward is: -660
# shifts:  [(8, '03:00'), (1, '09:00'), (1, '17:00'), (1, '01:00'), (0, '19:00'), (0, '19:00'), (0, '16:30'), (0, '17:30'), (0, '20:00'), (0, '07:00'), (0, '10:00')]
# number of available agents 1
# observation_space is: 1
# reward is: 0
# number of available agents 0
# observation_space is: 2
# reward is: 0
# number of available agents 0
# observation_space is: 3
# reward is: 0
# number of available agents 0
# observation_space is: 4
# reward is: -960
# shifts:  [(10, '01:30'), (1, '06:30'), (0, '20:00'), (0, '02:00')]
# number of available agents 0
# observation_space is: 4
# reward is: -960
# shifts:  [(10, '01:30'), (1, '06:30'), (0, '20:00'), (0, '02:00'), (0, '04:00')]
# number of available agents 0
# observation_space is: 4
# reward is: -960
# shifts:  [(10, '01:30'), (1, '06:30'), (0, '20:00'), (0, '02:00'), (0, '04:00'), (0, '13:00')]
# number of available agents 0
# observation_space is: 4
# reward is: -960
# shifts:  [(10, '01:30'), (1, '06:30'), (0, '20:00'), (0, '02:00'), (0, '04:00'), (0, '13:00'), (0, '14:30')]
# number of available agents 0
# observation_space is: 4
# reward is: -960
# shifts:  [(10, '01:30'), (1, '06:30'), (0, '20:00'), (0, '02:00'), (0, '04:00'), (0, '13:00'), (0, '14:30'), (0, '04:00')]
# number of available agents 0
# observation_space is: 4
# reward is: -960
# shifts:  [(10, '01:30'), (1, '06:30'), (0, '20:00'), (0, '02:00'), (0, '04:00'), (0, '13:00'), (0, '14:30'), (0, '04:00'), (0, '14:00')]
# number of available agents 0
# observation_space is: 4
# reward is: -960
# shifts:  [(10, '01:30'), (1, '06:30'), (0, '20:00'), (0, '02:00'), (0, '04:00'), (0, '13:00'), (0, '14:30'), (0, '04:00'), (0, '14:00'), (0, '10:30')]
# number of available agents 0
# observation_space is: 4
# reward is: -960
# shifts:  [(10, '01:30'), (1, '06:30'), (0, '20:00'), (0, '02:00'), (0, '04:00'), (0, '13:00'), (0, '14:30'), (0, '04:00'), (0, '14:00'), (0, '10:30'), (0, '08:30')]
# number of available agents 6
# observation_space is: 1
# reward is: 0
# number of available agents 1
# observation_space is: 2
# reward is: 0
# number of available agents 0
# observation_space is: 3
# reward is: 0
# number of available agents 0
# observation_space is: 4
# reward is: -600
# shifts:  [(5, '21:30'), (5, '03:30'), (1, '09:00'), (0, '16:30')]
# number of available agents 0
# observation_space is: 4
# reward is: -600
# shifts:  [(5, '21:30'), (5, '03:30'), (1, '09:00'), (0, '16:30'), (0, '12:30')]
# number of available agents 0
# observation_space is: 4
# reward is: -600
# shifts:  [(5, '21:30'), (5, '03:30'), (1, '09:00'), (0, '16:30'), (0, '12:30'), (0, '06:30')]
# number of available agents 0
# observation_space is: 4
# reward is: -600
# shifts:  [(5, '21:30'), (5, '03:30'), (1, '09:00'), (0, '16:30'), (0, '12:30'), (0, '06:30'), (0, '19:30')]
# number of available agents 0
# observation_space is: 4
# reward is: -600
# shifts:  [(5, '21:30'), (5, '03:30'), (1, '09:00'), (0, '16:30'), (0, '12:30'), (0, '06:30'), (0, '19:30'), (0, '06:00')]
# number of available agents 0
# observation_space is: 4
# reward is: -600
# shifts:  [(5, '21:30'), (5, '03:30'), (1, '09:00'), (0, '16:30'), (0, '12:30'), (0, '06:30'), (0, '19:30'), (0, '06:00'), (0, '15:30')]
# number of available agents 0
# observation_space is: 4
# reward is: -600
# shifts:  [(5, '21:30'), (5, '03:30'), (1, '09:00'), (0, '16:30'), (0, '12:30'), (0, '06:30'), (0, '19:30'), (0, '06:00'), (0, '15:30'), (0, '15:00')]
# number of available agents 0
# observation_space is: 4
# reward is: -600
# shifts:  [(5, '21:30'), (5, '03:30'), (1, '09:00'), (0, '16:30'), (0, '12:30'), (0, '06:30'), (0, '19:30'), (0, '06:00'), (0, '15:30'), (0, '15:00'), (0, '12:30')]
# number of available agents 2
# observation_space is: 1
# reward is: 0
# number of available agents 1
# observation_space is: 2
# reward is: 0
# number of available agents 0
# observation_space is: 3
# reward is: 0
# number of available agents 0
# observation_space is: 4
# reward is: -960
# shifts:  [(9, '03:00'), (1, '04:30'), (1, '02:00'), (0, '17:00')]
# number of available agents 0
# observation_space is: 4
# reward is: -960
# shifts:  [(9, '03:00'), (1, '04:30'), (1, '02:00'), (0, '17:00'), (0, '23:30')]
# number of available agents 0
# observation_space is: 4
# reward is: -960
# shifts:  [(9, '03:00'), (1, '04:30'), (1, '02:00'), (0, '17:00'), (0, '23:30'), (0, '11:00')]
# number of available agents 0
# observation_space is: 4
# reward is: -960
# shifts:  [(9, '03:00'), (1, '04:30'), (1, '02:00'), (0, '17:00'), (0, '23:30'), (0, '11:00'), (0, '12:30')]
# number of available agents 0
# observation_space is: 4
# reward is: -960
# shifts:  [(9, '03:00'), (1, '04:30'), (1, '02:00'), (0, '17:00'), (0, '23:30'), (0, '11:00'), (0, '12:30'), (0, '02:30')]
# number of available agents 0
# observation_space is: 4
# reward is: -960
# shifts:  [(9, '03:00'), (1, '04:30'), (1, '02:00'), (0, '17:00'), (0, '23:30'), (0, '11:00'), (0, '12:30'), (0, '02:30'), (0, '08:00')]
# number of available agents 0
# observation_space is: 4
# reward is: -960
# shifts:  [(9, '03:00'), (1, '04:30'), (1, '02:00'), (0, '17:00'), (0, '23:30'), (0, '11:00'), (0, '12:30'), (0, '02:30'), (0, '08:00'), (0, '17:00')]
# number of available agents 0
# observation_space is: 4
# reward is: -960
# shifts:  [(9, '03:00'), (1, '04:30'), (1, '02:00'), (0, '17:00'), (0, '23:30'), (0, '11:00'), (0, '12:30'), (0, '02:30'), (0, '08:00'), (0, '17:00'), (0, '14:00')]
# number of available agents 7
# observation_space is: 1
# reward is: 0
# number of available agents 1
# observation_space is: 2
# reward is: 0
# number of available agents 0
# observation_space is: 3
# reward is: 0
# number of available agents 0
# observation_space is: 4
# reward is: -660
# shifts:  [(4, '09:30'), (6, '12:30'), (1, '04:00'), (0, '10:00')]
# number of available agents 0
# observation_space is: 4
# reward is: -660
# shifts:  [(4, '09:30'), (6, '12:30'), (1, '04:00'), (0, '10:00'), (0, '09:30')]
# number of available agents 0
# observation_space is: 4
# reward is: -660
# shifts:  [(4, '09:30'), (6, '12:30'), (1, '04:00'), (0, '10:00'), (0, '09:30'), (0, '01:00')]
# number of available agents 0
# observation_space is: 4
# reward is: -660
# shifts:  [(4, '09:30'), (6, '12:30'), (1, '04:00'), (0, '10:00'), (0, '09:30'), (0, '01:00'), (0, '18:30')]
# number of available agents 0
# observation_space is: 4
# reward is: -660
# shifts:  [(4, '09:30'), (6, '12:30'), (1, '04:00'), (0, '10:00'), (0, '09:30'), (0, '01:00'), (0, '18:30'), (0, '04:00')]
# number of available agents 0
# observation_space is: 4
# reward is: -660
# shifts:  [(4, '09:30'), (6, '12:30'), (1, '04:00'), (0, '10:00'), (0, '09:30'), (0, '01:00'), (0, '18:30'), (0, '04:00'), (0, '05:30')]
# number of available agents 0
# observation_space is: 4
# reward is: -660
# shifts:  [(4, '09:30'), (6, '12:30'), (1, '04:00'), (0, '10:00'), (0, '09:30'), (0, '01:00'), (0, '18:30'), (0, '04:00'), (0, '05:30'), (0, '10:00')]
# number of available agents 0
# observation_space is: 4
# reward is: -660
# shifts:  [(4, '09:30'), (6, '12:30'), (1, '04:00'), (0, '10:00'), (0, '09:30'), (0, '01:00'), (0, '18:30'), (0, '04:00'), (0, '05:30'), (0, '10:00'), (0, '09:30')]
# number of available agents 10
# observation_space is: 1
# reward is: 0
# number of available agents 9
# observation_space is: 2
# reward is: 0
# number of available agents 4
# observation_space is: 3
# reward is: 0
# number of available agents 3
# observation_space is: 4
# reward is: -840
# shifts:  [(1, '09:00'), (1, '20:30'), (5, '16:00'), (1, '23:00')]
# number of available agents 3
# observation_space is: 4
# reward is: -660
# shifts:  [(1, '09:00'), (1, '20:30'), (5, '16:00'), (1, '23:00'), (1, '07:00')]
# number of available agents 3
# observation_space is: 4
# reward is: -360
# shifts:  [(1, '09:00'), (1, '20:30'), (5, '16:00'), (1, '23:00'), (1, '07:00'), (3, '05:00')]
# number of available agents 3
# observation_space is: 4
# reward is: -60
# shifts:  [(1, '09:00'), (1, '20:30'), (5, '16:00'), (1, '23:00'), (1, '07:00'), (3, '05:00'), (1, '20:30')]
# number of available agents 3
# observation_space is: 4
# reward is: 300
# shifts:  [(1, '09:00'), (1, '20:30'), (5, '16:00'), (1, '23:00'), (1, '07:00'), (3, '05:00'), (1, '20:30'), (3, '12:00')]
# number of available agents 3
# observation_space is: 4
# reward is: 360
# shifts:  [(1, '09:00'), (1, '20:30'), (5, '16:00'), (1, '23:00'), (1, '07:00'), (3, '05:00'), (1, '20:30'), (3, '12:00'), (3, '16:30')]
# number of available agents 3
# observation_space is: 4
# reward is: 360
# shifts:  [(1, '09:00'), (1, '20:30'), (5, '16:00'), (1, '23:00'), (1, '07:00'), (3, '05:00'), (1, '20:30'), (3, '12:00'), (3, '16:30'), (3, '16:30')]
# number of available agents 3
# observation_space is: 4
# reward is: 720
# shifts:  [(1, '09:00'), (1, '20:30'), (5, '16:00'), (1, '23:00'), (1, '07:00'), (3, '05:00'), (1, '20:30'), (3, '12:00'), (3, '16:30'), (3, '16:30'), (2, '00:30')]
# number of available agents 1
# observation_space is: 1
# reward is: 0
# number of available agents 0
# observation_space is: 2
# reward is: 0
# number of available agents 0
# observation_space is: 3
# reward is: 0
# number of available agents 0
# observation_space is: 4
# reward is: -960
# shifts:  [(10, '02:30'), (1, '13:30'), (0, '18:00'), (0, '02:00')]
# number of available agents 0
# observation_space is: 4
# reward is: -960
# shifts:  [(10, '02:30'), (1, '13:30'), (0, '18:00'), (0, '02:00'), (0, '00:30')]
# number of available agents 0
# observation_space is: 4
# reward is: -960
# shifts:  [(10, '02:30'), (1, '13:30'), (0, '18:00'), (0, '02:00'), (0, '00:30'), (0, '03:00')]
# number of available agents 0
# observation_space is: 4
# reward is: -960
# shifts:  [(10, '02:30'), (1, '13:30'), (0, '18:00'), (0, '02:00'), (0, '00:30'), (0, '03:00'), (0, '13:00')]
# number of available agents 0
# observation_space is: 4
# reward is: -960
# shifts:  [(10, '02:30'), (1, '13:30'), (0, '18:00'), (0, '02:00'), (0, '00:30'), (0, '03:00'), (0, '13:00'), (0, '19:30')]
# number of available agents 0
# observation_space is: 4
# reward is: -960
# shifts:  [(10, '02:30'), (1, '13:30'), (0, '18:00'), (0, '02:00'), (0, '00:30'), (0, '03:00'), (0, '13:00'), (0, '19:30'), (0, '17:00')]
# number of available agents 0
# observation_space is: 4
# reward is: -960
# shifts:  [(10, '02:30'), (1, '13:30'), (0, '18:00'), (0, '02:00'), (0, '00:30'), (0, '03:00'), (0, '13:00'), (0, '19:30'), (0, '17:00'), (0, '12:00')]
# number of available agents 0
# observation_space is: 4
# reward is: -960
# shifts:  [(10, '02:30'), (1, '13:30'), (0, '18:00'), (0, '02:00'), (0, '00:30'), (0, '03:00'), (0, '13:00'), (0, '19:30'), (0, '17:00'), (0, '12:00'), (0, '10:00')]
# number of available agents 10
# observation_space is: 1
# reward is: 0
# number of available agents 1
# observation_space is: 2
# reward is: 0
# number of available agents 0
# observation_space is: 3
# reward is: 0
# number of available agents 0
# observation_space is: 4
# reward is: -900
# shifts:  [(1, '07:30'), (9, '21:30'), (1, '10:00'), (0, '02:00')]
# number of available agents 0
# observation_space is: 4
# reward is: -900
# shifts:  [(1, '07:30'), (9, '21:30'), (1, '10:00'), (0, '02:00'), (0, '09:30')]
# number of available agents 0
# observation_space is: 4
# reward is: -900
# shifts:  [(1, '07:30'), (9, '21:30'), (1, '10:00'), (0, '02:00'), (0, '09:30'), (0, '01:30')]
# number of available agents 0
# observation_space is: 4
# reward is: -900
# shifts:  [(1, '07:30'), (9, '21:30'), (1, '10:00'), (0, '02:00'), (0, '09:30'), (0, '01:30'), (0, '14:30')]
# number of available agents 0
# observation_space is: 4
# reward is: -900
# shifts:  [(1, '07:30'), (9, '21:30'), (1, '10:00'), (0, '02:00'), (0, '09:30'), (0, '01:30'), (0, '14:30'), (0, '05:30')]
# number of available agents 0
# observation_space is: 4
# reward is: -900
# shifts:  [(1, '07:30'), (9, '21:30'), (1, '10:00'), (0, '02:00'), (0, '09:30'), (0, '01:30'), (0, '14:30'), (0, '05:30'), (0, '14:30')]
# number of available agents 0
# observation_space is: 4
# reward is: -900
# shifts:  [(1, '07:30'), (9, '21:30'), (1, '10:00'), (0, '02:00'), (0, '09:30'), (0, '01:30'), (0, '14:30'), (0, '05:30'), (0, '14:30'), (0, '18:30')]
# number of available agents 0
# observation_space is: 4
# reward is: -900
# shifts:  [(1, '07:30'), (9, '21:30'), (1, '10:00'), (0, '02:00'), (0, '09:30'), (0, '01:30'), (0, '14:30'), (0, '05:30'), (0, '14:30'), (0, '18:30'), (0, '13:30')]
# number of available agents 5
# observation_space is: 1
# reward is: 0
# number of available agents 3
# observation_space is: 2
# reward is: 0
# number of available agents 2
# observation_space is: 3
# reward is: 0
# number of available agents 0
# observation_space is: 4
# reward is: -240
# shifts:  [(6, '03:30'), (2, '18:00'), (1, '10:00'), (2, '20:30')]
# number of available agents 0
# observation_space is: 4
# reward is: -240
# shifts:  [(6, '03:30'), (2, '18:00'), (1, '10:00'), (2, '20:30'), (0, '14:30')]
# number of available agents 0
# observation_space is: 4
# reward is: -240
# shifts:  [(6, '03:30'), (2, '18:00'), (1, '10:00'), (2, '20:30'), (0, '14:30'), (0, '13:00')]
# number of available agents 0
# observation_space is: 4
# reward is: -240
# shifts:  [(6, '03:30'), (2, '18:00'), (1, '10:00'), (2, '20:30'), (0, '14:30'), (0, '13:00'), (0, '23:00')]
# number of available agents 0
# observation_space is: 4
# reward is: -240
# shifts:  [(6, '03:30'), (2, '18:00'), (1, '10:00'), (2, '20:30'), (0, '14:30'), (0, '13:00'), (0, '23:00'), (0, '00:30')]
# number of available agents 0
# observation_space is: 4
# reward is: -240
# shifts:  [(6, '03:30'), (2, '18:00'), (1, '10:00'), (2, '20:30'), (0, '14:30'), (0, '13:00'), (0, '23:00'), (0, '00:30'), (0, '04:30')]
# number of available agents 0
# observation_space is: 4
# reward is: -240
# shifts:  [(6, '03:30'), (2, '18:00'), (1, '10:00'), (2, '20:30'), (0, '14:30'), (0, '13:00'), (0, '23:00'), (0, '00:30'), (0, '04:30'), (0, '01:00')]
# number of available agents 0
# observation_space is: 4
# reward is: -240
# shifts:  [(6, '03:30'), (2, '18:00'), (1, '10:00'), (2, '20:30'), (0, '14:30'), (0, '13:00'), (0, '23:00'), (0, '00:30'), (0, '04:30'), (0, '01:00'), (0, '02:00')]
# number of available agents 7
# observation_space is: 1
# reward is: 0
# number of available agents 0
# observation_space is: 2
# reward is: 0
# number of available agents 0
# observation_space is: 3
# reward is: 0
# number of available agents 0
# observation_space is: 4
# reward is: -840
# shifts:  [(4, '15:00'), (7, '16:30'), (0, '13:00'), (0, '05:00')]
# number of available agents 0
# observation_space is: 4
# reward is: -840
# shifts:  [(4, '15:00'), (7, '16:30'), (0, '13:00'), (0, '05:00'), (0, '12:30')]
# number of available agents 0
# observation_space is: 4
# reward is: -840
# shifts:  [(4, '15:00'), (7, '16:30'), (0, '13:00'), (0, '05:00'), (0, '12:30'), (0, '15:00')]
# number of available agents 0
# observation_space is: 4
# reward is: -840
# shifts:  [(4, '15:00'), (7, '16:30'), (0, '13:00'), (0, '05:00'), (0, '12:30'), (0, '15:00'), (0, '10:30')]
# number of available agents 0
# observation_space is: 4
# reward is: -840
# shifts:  [(4, '15:00'), (7, '16:30'), (0, '13:00'), (0, '05:00'), (0, '12:30'), (0, '15:00'), (0, '10:30'), (0, '19:00')]
# number of available agents 0
# observation_space is: 4
# reward is: -840
# shifts:  [(4, '15:00'), (7, '16:30'), (0, '13:00'), (0, '05:00'), (0, '12:30'), (0, '15:00'), (0, '10:30'), (0, '19:00'), (0, '22:30')]
# number of available agents 0
# observation_space is: 4
# reward is: -840
# shifts:  [(4, '15:00'), (7, '16:30'), (0, '13:00'), (0, '05:00'), (0, '12:30'), (0, '15:00'), (0, '10:30'), (0, '19:00'), (0, '22:30'), (0, '03:30')]
# number of available agents 0
# observation_space is: 4
# reward is: -840
# shifts:  [(4, '15:00'), (7, '16:30'), (0, '13:00'), (0, '05:00'), (0, '12:30'), (0, '15:00'), (0, '10:30'), (0, '19:00'), (0, '22:30'), (0, '03:30'), (0, '07:00')]
# number of available agents 4
# observation_space is: 1
# reward is: 0
# number of available agents 1
# observation_space is: 2
# reward is: 0
# number of available agents 0
# observation_space is: 3
# reward is: 0
# number of available agents 0
# observation_space is: 4
# reward is: -480
# shifts:  [(7, '00:00'), (3, '03:00'), (1, '10:00'), (0, '01:30')]
# number of available agents 0
# observation_space is: 4
# reward is: -480
# shifts:  [(7, '00:00'), (3, '03:00'), (1, '10:00'), (0, '01:30'), (0, '06:30')]
# number of available agents 0
# observation_space is: 4
# reward is: -480
# shifts:  [(7, '00:00'), (3, '03:00'), (1, '10:00'), (0, '01:30'), (0, '06:30'), (0, '08:00')]
# number of available agents 0
# observation_space is: 4
# reward is: -480
# shifts:  [(7, '00:00'), (3, '03:00'), (1, '10:00'), (0, '01:30'), (0, '06:30'), (0, '08:00'), (0, '08:30')]
# number of available agents 0
# observation_space is: 4
# reward is: -480
# shifts:  [(7, '00:00'), (3, '03:00'), (1, '10:00'), (0, '01:30'), (0, '06:30'), (0, '08:00'), (0, '08:30'), (0, '14:00')]
# number of available agents 0
# observation_space is: 4
# reward is: -480
# shifts:  [(7, '00:00'), (3, '03:00'), (1, '10:00'), (0, '01:30'), (0, '06:30'), (0, '08:00'), (0, '08:30'), (0, '14:00'), (0, '00:00')]
# number of available agents 0
# observation_space is: 4
# reward is: -480
# shifts:  [(7, '00:00'), (3, '03:00'), (1, '10:00'), (0, '01:30'), (0, '06:30'), (0, '08:00'), (0, '08:30'), (0, '14:00'), (0, '00:00'), (0, '00:00')]
# number of available agents 0
# observation_space is: 4
# reward is: -480
# shifts:  [(7, '00:00'), (3, '03:00'), (1, '10:00'), (0, '01:30'), (0, '06:30'), (0, '08:00'), (0, '08:30'), (0, '14:00'), (0, '00:00'), (0, '00:00'), (0, '01:00')]
# number of available agents 8
# observation_space is: 1
# reward is: 0
# number of available agents 6
# observation_space is: 2
# reward is: 0
# number of available agents 3
# observation_space is: 3
# reward is: 0
# number of available agents 0
# observation_space is: 4
# reward is: -660
# shifts:  [(3, '09:00'), (2, '01:00'), (3, '01:00'), (3, '00:30')]
# number of available agents 0
# observation_space is: 4
# reward is: -660
# shifts:  [(3, '09:00'), (2, '01:00'), (3, '01:00'), (3, '00:30'), (0, '07:00')]
# number of available agents 0
# observation_space is: 4
# reward is: -660
# shifts:  [(3, '09:00'), (2, '01:00'), (3, '01:00'), (3, '00:30'), (0, '07:00'), (0, '19:00')]
# number of available agents 0
# observation_space is: 4
# reward is: -660
# shifts:  [(3, '09:00'), (2, '01:00'), (3, '01:00'), (3, '00:30'), (0, '07:00'), (0, '19:00'), (0, '10:00')]
# number of available agents 0
# observation_space is: 4
# reward is: -660
# shifts:  [(3, '09:00'), (2, '01:00'), (3, '01:00'), (3, '00:30'), (0, '07:00'), (0, '19:00'), (0, '10:00'), (0, '22:00')]
# number of available agents 0
# observation_space is: 4
# reward is: -660
# shifts:  [(3, '09:00'), (2, '01:00'), (3, '01:00'), (3, '00:30'), (0, '07:00'), (0, '19:00'), (0, '10:00'), (0, '22:00'), (0, '17:00')]
# number of available agents 0
# observation_space is: 4
# reward is: -660
# shifts:  [(3, '09:00'), (2, '01:00'), (3, '01:00'), (3, '00:30'), (0, '07:00'), (0, '19:00'), (0, '10:00'), (0, '22:00'), (0, '17:00'), (0, '14:00')]
# number of available agents 0
# observation_space is: 4
# reward is: -660
# shifts:  [(3, '09:00'), (2, '01:00'), (3, '01:00'), (3, '00:30'), (0, '07:00'), (0, '19:00'), (0, '10:00'), (0, '22:00'), (0, '17:00'), (0, '14:00'), (0, '22:00')]
# number of available agents 7
# observation_space is: 1
# reward is: 0
# number of available agents 2
# observation_space is: 2
# reward is: 0
# number of available agents 1
# observation_space is: 3
# reward is: 0
# number of available agents 0
# observation_space is: 4
# reward is: -780
# shifts:  [(4, '06:30'), (5, '05:00'), (1, '01:00'), (1, '06:00')]
# number of available agents 0
# observation_space is: 4
# reward is: -780
# shifts:  [(4, '06:30'), (5, '05:00'), (1, '01:00'), (1, '06:00'), (0, '22:00')]
# number of available agents 0
# observation_space is: 4
# reward is: -780
# shifts:  [(4, '06:30'), (5, '05:00'), (1, '01:00'), (1, '06:00'), (0, '22:00'), (0, '17:30')]
# number of available agents 0
# observation_space is: 4
# reward is: -780
# shifts:  [(4, '06:30'), (5, '05:00'), (1, '01:00'), (1, '06:00'), (0, '22:00'), (0, '17:30'), (0, '04:00')]
# number of available agents 0
# observation_space is: 4
# reward is: -780
# shifts:  [(4, '06:30'), (5, '05:00'), (1, '01:00'), (1, '06:00'), (0, '22:00'), (0, '17:30'), (0, '04:00'), (0, '09:00')]
# number of available agents 0
# observation_space is: 4
# reward is: -780
# shifts:  [(4, '06:30'), (5, '05:00'), (1, '01:00'), (1, '06:00'), (0, '22:00'), (0, '17:30'), (0, '04:00'), (0, '09:00'), (0, '15:30')]
# number of available agents 0
# observation_space is: 4
# reward is: -780
# shifts:  [(4, '06:30'), (5, '05:00'), (1, '01:00'), (1, '06:00'), (0, '22:00'), (0, '17:30'), (0, '04:00'), (0, '09:00'), (0, '15:30'), (0, '16:30')]
# number of available agents 0
# observation_space is: 4
# reward is: -780
# shifts:  [(4, '06:30'), (5, '05:00'), (1, '01:00'), (1, '06:00'), (0, '22:00'), (0, '17:30'), (0, '04:00'), (0, '09:00'), (0, '15:30'), (0, '16:30'), (0, '18:00')]
# number of available agents 3
# observation_space is: 1
# reward is: 0
# number of available agents 0
# observation_space is: 2
# reward is: 0
# number of available agents 0
# observation_space is: 3
# reward is: 0
# number of available agents 0
# observation_space is: 4
# reward is: -840
# shifts:  [(8, '22:30'), (3, '08:30'), (0, '16:00'), (0, '08:30')]
# number of available agents 0
# observation_space is: 4
# reward is: -840
# shifts:  [(8, '22:30'), (3, '08:30'), (0, '16:00'), (0, '08:30'), (0, '13:00')]
# number of available agents 0
# observation_space is: 4
# reward is: -840
# shifts:  [(8, '22:30'), (3, '08:30'), (0, '16:00'), (0, '08:30'), (0, '13:00'), (0, '22:30')]
# number of available agents 0
# observation_space is: 4
# reward is: -840
# shifts:  [(8, '22:30'), (3, '08:30'), (0, '16:00'), (0, '08:30'), (0, '13:00'), (0, '22:30'), (0, '01:00')]
# number of available agents 0
# observation_space is: 4
# reward is: -840
# shifts:  [(8, '22:30'), (3, '08:30'), (0, '16:00'), (0, '08:30'), (0, '13:00'), (0, '22:30'), (0, '01:00'), (0, '00:30')]
# number of available agents 0
# observation_space is: 4
# reward is: -840
# shifts:  [(8, '22:30'), (3, '08:30'), (0, '16:00'), (0, '08:30'), (0, '13:00'), (0, '22:30'), (0, '01:00'), (0, '00:30'), (0, '12:00')]
# number of available agents 0
# observation_space is: 4
# reward is: -840
# shifts:  [(8, '22:30'), (3, '08:30'), (0, '16:00'), (0, '08:30'), (0, '13:00'), (0, '22:30'), (0, '01:00'), (0, '00:30'), (0, '12:00'), (0, '14:00')]
# number of available agents 0
# observation_space is: 4
# reward is: -840
# shifts:  [(8, '22:30'), (3, '08:30'), (0, '16:00'), (0, '08:30'), (0, '13:00'), (0, '22:30'), (0, '01:00'), (0, '00:30'), (0, '12:00'), (0, '14:00'), (0, '08:30')]
# number of available agents 6
# observation_space is: 1
# reward is: 0
# number of available agents 0
# observation_space is: 2
# reward is: 0
# number of available agents 0
# observation_space is: 3
# reward is: 0
# number of available agents 0
# observation_space is: 4
# reward is: -840
# shifts:  [(5, '09:00'), (6, '11:00'), (0, '07:30'), (0, '22:30')]
# number of available agents 0
# observation_space is: 4
# reward is: -840
# shifts:  [(5, '09:00'), (6, '11:00'), (0, '07:30'), (0, '22:30'), (0, '08:30')]
# number of available agents 0
# observation_space is: 4
# reward is: -840
# shifts:  [(5, '09:00'), (6, '11:00'), (0, '07:30'), (0, '22:30'), (0, '08:30'), (0, '13:00')]
# number of available agents 0
# observation_space is: 4
# reward is: -840
# shifts:  [(5, '09:00'), (6, '11:00'), (0, '07:30'), (0, '22:30'), (0, '08:30'), (0, '13:00'), (0, '05:00')]
# number of available agents 0
# observation_space is: 4
# reward is: -840
# shifts:  [(5, '09:00'), (6, '11:00'), (0, '07:30'), (0, '22:30'), (0, '08:30'), (0, '13:00'), (0, '05:00'), (0, '05:00')]
# number of available agents 0
# observation_space is: 4
# reward is: -840
# shifts:  [(5, '09:00'), (6, '11:00'), (0, '07:30'), (0, '22:30'), (0, '08:30'), (0, '13:00'), (0, '05:00'), (0, '05:00'), (0, '04:30')]
# number of available agents 0
# observation_space is: 4
# reward is: -840
# shifts:  [(5, '09:00'), (6, '11:00'), (0, '07:30'), (0, '22:30'), (0, '08:30'), (0, '13:00'), (0, '05:00'), (0, '05:00'), (0, '04:30'), (0, '22:30')]
# number of available agents 0
# observation_space is: 4
# reward is: -840
# shifts:  [(5, '09:00'), (6, '11:00'), (0, '07:30'), (0, '22:30'), (0, '08:30'), (0, '13:00'), (0, '05:00'), (0, '05:00'), (0, '04:30'), (0, '22:30'), (0, '20:00')]
# number of available agents 8
# observation_space is: 1
# reward is: 0
# number of available agents 3
# observation_space is: 2
# reward is: 0
# number of available agents 2
# observation_space is: 3
# reward is: 0
# number of available agents 1
# observation_space is: 4
# reward is: -720
# shifts:  [(3, '14:00'), (5, '15:30'), (1, '09:00'), (1, '23:30')]
# number of available agents 1
# observation_space is: 4
# reward is: -600
# shifts:  [(3, '14:00'), (5, '15:30'), (1, '09:00'), (1, '23:30'), (1, '13:00')]
# number of available agents 1
# observation_space is: 4
# reward is: -480
# shifts:  [(3, '14:00'), (5, '15:30'), (1, '09:00'), (1, '23:30'), (1, '13:00'), (1, '17:00')]
# number of available agents 1
# observation_space is: 4
# reward is: -360
# shifts:  [(3, '14:00'), (5, '15:30'), (1, '09:00'), (1, '23:30'), (1, '13:00'), (1, '17:00'), (1, '05:30')]
# number of available agents 1
# observation_space is: 4
# reward is: -120
# shifts:  [(3, '14:00'), (5, '15:30'), (1, '09:00'), (1, '23:30'), (1, '13:00'), (1, '17:00'), (1, '05:30'), (1, '06:30')]
# number of available agents 1
# observation_space is: 4
# reward is: -60
# shifts:  [(3, '14:00'), (5, '15:30'), (1, '09:00'), (1, '23:30'), (1, '13:00'), (1, '17:00'), (1, '05:30'), (1, '06:30'), (1, '05:30')]
# number of available agents 1
# observation_space is: 4
# reward is: -60
# shifts:  [(3, '14:00'), (5, '15:30'), (1, '09:00'), (1, '23:30'), (1, '13:00'), (1, '17:00'), (1, '05:30'), (1, '06:30'), (1, '05:30'), (1, '02:00')]
# number of available agents 1
# observation_space is: 4
# reward is: 0
# shifts:  [(3, '14:00'), (5, '15:30'), (1, '09:00'), (1, '23:30'), (1, '13:00'), (1, '17:00'), (1, '05:30'), (1, '06:30'), (1, '05:30'), (1, '02:00'), (1, '04:30')]
# number of available agents 2
# observation_space is: 1
# reward is: 0
# number of available agents 1
# observation_space is: 2
# reward is: 0
# number of available agents 0
# observation_space is: 3
# reward is: 0
# number of available agents 0
# observation_space is: 4
# reward is: -780
# shifts:  [(9, '00:30'), (1, '19:00'), (1, '10:00'), (0, '15:30')]
# number of available agents 0
# observation_space is: 4
# reward is: -780
# shifts:  [(9, '00:30'), (1, '19:00'), (1, '10:00'), (0, '15:30'), (0, '05:00')]
# number of available agents 0
# observation_space is: 4
# reward is: -780
# shifts:  [(9, '00:30'), (1, '19:00'), (1, '10:00'), (0, '15:30'), (0, '05:00'), (0, '15:30')]
# number of available agents 0
# observation_space is: 4
# reward is: -780
# shifts:  [(9, '00:30'), (1, '19:00'), (1, '10:00'), (0, '15:30'), (0, '05:00'), (0, '15:30'), (0, '14:30')]
# number of available agents 0
# observation_space is: 4
# reward is: -780
# shifts:  [(9, '00:30'), (1, '19:00'), (1, '10:00'), (0, '15:30'), (0, '05:00'), (0, '15:30'), (0, '14:30'), (0, '19:00')]
# number of available agents 0
# observation_space is: 4
# reward is: -780
# shifts:  [(9, '00:30'), (1, '19:00'), (1, '10:00'), (0, '15:30'), (0, '05:00'), (0, '15:30'), (0, '14:30'), (0, '19:00'), (0, '23:30')]
# number of available agents 0
# observation_space is: 4
# reward is: -780
# shifts:  [(9, '00:30'), (1, '19:00'), (1, '10:00'), (0, '15:30'), (0, '05:00'), (0, '15:30'), (0, '14:30'), (0, '19:00'), (0, '23:30'), (0, '20:00')]
# number of available agents 0
# observation_space is: 4
# reward is: -780
# shifts:  [(9, '00:30'), (1, '19:00'), (1, '10:00'), (0, '15:30'), (0, '05:00'), (0, '15:30'), (0, '14:30'), (0, '19:00'), (0, '23:30'), (0, '20:00'), (0, '14:30')]
# number of available agents 1
# observation_space is: 1
# reward is: 0
# number of available agents 0
# observation_space is: 2
# reward is: 0
# number of available agents 0
# observation_space is: 3
# reward is: 0
# number of available agents 0
# observation_space is: 4
# reward is: -1020
# shifts:  [(10, '12:00'), (1, '01:30'), (0, '09:00'), (0, '18:00')]
# number of available agents 0
# observation_space is: 4
# reward is: -1020
# shifts:  [(10, '12:00'), (1, '01:30'), (0, '09:00'), (0, '18:00'), (0, '06:30')]
# number of available agents 0
# observation_space is: 4
# reward is: -1020
# shifts:  [(10, '12:00'), (1, '01:30'), (0, '09:00'), (0, '18:00'), (0, '06:30'), (0, '05:30')]
# number of available agents 0
# observation_space is: 4
# reward is: -1020
# shifts:  [(10, '12:00'), (1, '01:30'), (0, '09:00'), (0, '18:00'), (0, '06:30'), (0, '05:30'), (0, '21:30')]
# number of available agents 0
# observation_space is: 4
# reward is: -1020
# shifts:  [(10, '12:00'), (1, '01:30'), (0, '09:00'), (0, '18:00'), (0, '06:30'), (0, '05:30'), (0, '21:30'), (0, '06:00')]
# number of available agents 0
# observation_space is: 4
# reward is: -1020
# shifts:  [(10, '12:00'), (1, '01:30'), (0, '09:00'), (0, '18:00'), (0, '06:30'), (0, '05:30'), (0, '21:30'), (0, '06:00'), (0, '10:00')]
# number of available agents 0
# observation_space is: 4
# reward is: -1020
# shifts:  [(10, '12:00'), (1, '01:30'), (0, '09:00'), (0, '18:00'), (0, '06:30'), (0, '05:30'), (0, '21:30'), (0, '06:00'), (0, '10:00'), (0, '00:30')]
# number of available agents 0
# observation_space is: 4
# reward is: -1020
# shifts:  [(10, '12:00'), (1, '01:30'), (0, '09:00'), (0, '18:00'), (0, '06:30'), (0, '05:30'), (0, '21:30'), (0, '06:00'), (0, '10:00'), (0, '00:30'), (0, '04:30')]
# number of available agents 6
# observation_space is: 1
# reward is: 0
# number of available agents 5
# observation_space is: 2
# reward is: 0
# number of available agents 1
# observation_space is: 3
# reward is: 0
# number of available agents 0
# observation_space is: 4
# reward is: -660
# shifts:  [(5, '01:00'), (1, '14:30'), (4, '17:30'), (1, '04:00')]
# number of available agents 0
# observation_space is: 4
# reward is: -660
# shifts:  [(5, '01:00'), (1, '14:30'), (4, '17:30'), (1, '04:00'), (0, '21:00')]
# number of available agents 0
# observation_space is: 4
# reward is: -660
# shifts:  [(5, '01:00'), (1, '14:30'), (4, '17:30'), (1, '04:00'), (0, '21:00'), (0, '20:00')]
# number of available agents 0
# observation_space is: 4
# reward is: -660
# shifts:  [(5, '01:00'), (1, '14:30'), (4, '17:30'), (1, '04:00'), (0, '21:00'), (0, '20:00'), (0, '21:00')]
# number of available agents 0
# observation_space is: 4
# reward is: -660
# shifts:  [(5, '01:00'), (1, '14:30'), (4, '17:30'), (1, '04:00'), (0, '21:00'), (0, '20:00'), (0, '21:00'), (0, '01:30')]
# number of available agents 0
# observation_space is: 4
# reward is: -660
# shifts:  [(5, '01:00'), (1, '14:30'), (4, '17:30'), (1, '04:00'), (0, '21:00'), (0, '20:00'), (0, '21:00'), (0, '01:30'), (0, '11:00')]
# number of available agents 0
# observation_space is: 4
# reward is: -660
# shifts:  [(5, '01:00'), (1, '14:30'), (4, '17:30'), (1, '04:00'), (0, '21:00'), (0, '20:00'), (0, '21:00'), (0, '01:30'), (0, '11:00'), (0, '17:00')]
# number of available agents 0
# observation_space is: 4
# reward is: -660
# shifts:  [(5, '01:00'), (1, '14:30'), (4, '17:30'), (1, '04:00'), (0, '21:00'), (0, '20:00'), (0, '21:00'), (0, '01:30'), (0, '11:00'), (0, '17:00'), (0, '11:00')]
# number of available agents 10
# observation_space is: 1
# reward is: 0
# number of available agents 3
# observation_space is: 2
# reward is: 0
# number of available agents 1
# observation_space is: 3
# reward is: 0
# number of available agents 0
# observation_space is: 4
# reward is: -600
# shifts:  [(1, '05:00'), (7, '03:00'), (2, '15:00'), (1, '20:30')]
# number of available agents 0
# observation_space is: 4
# reward is: -600
# shifts:  [(1, '05:00'), (7, '03:00'), (2, '15:00'), (1, '20:30'), (0, '11:00')]
# number of available agents 0
# observation_space is: 4
# reward is: -600
# shifts:  [(1, '05:00'), (7, '03:00'), (2, '15:00'), (1, '20:30'), (0, '11:00'), (0, '20:00')]
# number of available agents 0
# observation_space is: 4
# reward is: -600
# shifts:  [(1, '05:00'), (7, '03:00'), (2, '15:00'), (1, '20:30'), (0, '11:00'), (0, '20:00'), (0, '22:30')]
# number of available agents 0
# observation_space is: 4
# reward is: -600
# shifts:  [(1, '05:00'), (7, '03:00'), (2, '15:00'), (1, '20:30'), (0, '11:00'), (0, '20:00'), (0, '22:30'), (0, '01:00')]
# number of available agents 0
# observation_space is: 4
# reward is: -600
# shifts:  [(1, '05:00'), (7, '03:00'), (2, '15:00'), (1, '20:30'), (0, '11:00'), (0, '20:00'), (0, '22:30'), (0, '01:00'), (0, '09:30')]
# number of available agents 0
# observation_space is: 4
# reward is: -600
# shifts:  [(1, '05:00'), (7, '03:00'), (2, '15:00'), (1, '20:30'), (0, '11:00'), (0, '20:00'), (0, '22:30'), (0, '01:00'), (0, '09:30'), (0, '19:00')]
# number of available agents 0
# observation_space is: 4
# reward is: -600
# shifts:  [(1, '05:00'), (7, '03:00'), (2, '15:00'), (1, '20:30'), (0, '11:00'), (0, '20:00'), (0, '22:30'), (0, '01:00'), (0, '09:30'), (0, '19:00'), (0, '09:30')]
# number of available agents 8
# observation_space is: 1
# reward is: 0
# number of available agents 7
# observation_space is: 2
# reward is: 0
# number of available agents 0
# observation_space is: 3
# reward is: 0
# number of available agents 0
# observation_space is: 4
# reward is: -600
# shifts:  [(3, '03:00'), (1, '05:30'), (7, '08:00'), (0, '06:00')]
# number of available agents 0
# observation_space is: 4
# reward is: -600
# shifts:  [(3, '03:00'), (1, '05:30'), (7, '08:00'), (0, '06:00'), (0, '05:30')]
# number of available agents 0
# observation_space is: 4
# reward is: -600
# shifts:  [(3, '03:00'), (1, '05:30'), (7, '08:00'), (0, '06:00'), (0, '05:30'), (0, '08:30')]
# number of available agents 0
# observation_space is: 4
# reward is: -600
# shifts:  [(3, '03:00'), (1, '05:30'), (7, '08:00'), (0, '06:00'), (0, '05:30'), (0, '08:30'), (0, '06:00')]
# number of available agents 0
# observation_space is: 4
# reward is: -600
# shifts:  [(3, '03:00'), (1, '05:30'), (7, '08:00'), (0, '06:00'), (0, '05:30'), (0, '08:30'), (0, '06:00'), (0, '22:30')]
# number of available agents 0
# observation_space is: 4
# reward is: -600
# shifts:  [(3, '03:00'), (1, '05:30'), (7, '08:00'), (0, '06:00'), (0, '05:30'), (0, '08:30'), (0, '06:00'), (0, '22:30'), (0, '02:00')]
# number of available agents 0
# observation_space is: 4
# reward is: -600
# shifts:  [(3, '03:00'), (1, '05:30'), (7, '08:00'), (0, '06:00'), (0, '05:30'), (0, '08:30'), (0, '06:00'), (0, '22:30'), (0, '02:00'), (0, '03:00')]
# number of available agents 0
# observation_space is: 4
# reward is: -600
# shifts:  [(3, '03:00'), (1, '05:30'), (7, '08:00'), (0, '06:00'), (0, '05:30'), (0, '08:30'), (0, '06:00'), (0, '22:30'), (0, '02:00'), (0, '03:00'), (0, '20:00')]
# number of available agents 3
# observation_space is: 1
# reward is: 0
# number of available agents 0
# observation_space is: 2
# reward is: 0
# number of available agents 0
# observation_space is: 3
# reward is: 0
# number of available agents 0
# observation_space is: 4
# reward is: -660
# shifts:  [(8, '16:00'), (3, '05:00'), (0, '00:30'), (0, '16:30')]
# number of available agents 0
# observation_space is: 4
# reward is: -660
# shifts:  [(8, '16:00'), (3, '05:00'), (0, '00:30'), (0, '16:30'), (0, '09:30')]
# number of available agents 0
# observation_space is: 4
# reward is: -660
# shifts:  [(8, '16:00'), (3, '05:00'), (0, '00:30'), (0, '16:30'), (0, '09:30'), (0, '06:00')]
# number of available agents 0
# observation_space is: 4
# reward is: -660
# shifts:  [(8, '16:00'), (3, '05:00'), (0, '00:30'), (0, '16:30'), (0, '09:30'), (0, '06:00'), (0, '18:30')]
# number of available agents 0
# observation_space is: 4
# reward is: -660
# shifts:  [(8, '16:00'), (3, '05:00'), (0, '00:30'), (0, '16:30'), (0, '09:30'), (0, '06:00'), (0, '18:30'), (0, '06:00')]
# number of available agents 0
# observation_space is: 4
# reward is: -660
# shifts:  [(8, '16:00'), (3, '05:00'), (0, '00:30'), (0, '16:30'), (0, '09:30'), (0, '06:00'), (0, '18:30'), (0, '06:00'), (0, '05:30')]
# number of available agents 0
# observation_space is: 4
# reward is: -660
# shifts:  [(8, '16:00'), (3, '05:00'), (0, '00:30'), (0, '16:30'), (0, '09:30'), (0, '06:00'), (0, '18:30'), (0, '06:00'), (0, '05:30'), (0, '09:00')]
# number of available agents 0
# observation_space is: 4
# reward is: -660
# shifts:  [(8, '16:00'), (3, '05:00'), (0, '00:30'), (0, '16:30'), (0, '09:30'), (0, '06:00'), (0, '18:30'), (0, '06:00'), (0, '05:30'), (0, '09:00'), (0, '22:00')]
# number of available agents 8
# observation_space is: 1
# reward is: 0
# number of available agents 3
# observation_space is: 2
# reward is: 0
# number of available agents 2
# observation_space is: 3
# reward is: 0
# number of available agents 0
# observation_space is: 4
# reward is: -240
# shifts:  [(3, '02:30'), (5, '12:00'), (1, '03:30'), (2, '15:30')]
# number of available agents 0
# observation_space is: 4
# reward is: -240
# shifts:  [(3, '02:30'), (5, '12:00'), (1, '03:30'), (2, '15:30'), (0, '11:30')]
# number of available agents 0
# observation_space is: 4
# reward is: -240
# shifts:  [(3, '02:30'), (5, '12:00'), (1, '03:30'), (2, '15:30'), (0, '11:30'), (0, '01:30')]
# number of available agents 0
# observation_space is: 4
# reward is: -240
# shifts:  [(3, '02:30'), (5, '12:00'), (1, '03:30'), (2, '15:30'), (0, '11:30'), (0, '01:30'), (0, '07:30')]
# number of available agents 0
# observation_space is: 4
# reward is: -240
# shifts:  [(3, '02:30'), (5, '12:00'), (1, '03:30'), (2, '15:30'), (0, '11:30'), (0, '01:30'), (0, '07:30'), (0, '05:30')]
# number of available agents 0
# observation_space is: 4
# reward is: -240
# shifts:  [(3, '02:30'), (5, '12:00'), (1, '03:30'), (2, '15:30'), (0, '11:30'), (0, '01:30'), (0, '07:30'), (0, '05:30'), (0, '11:00')]
# number of available agents 0
# observation_space is: 4
# reward is: -240
# shifts:  [(3, '02:30'), (5, '12:00'), (1, '03:30'), (2, '15:30'), (0, '11:30'), (0, '01:30'), (0, '07:30'), (0, '05:30'), (0, '11:00'), (0, '12:30')]
# number of available agents 0
# observation_space is: 4
# reward is: -240
# shifts:  [(3, '02:30'), (5, '12:00'), (1, '03:30'), (2, '15:30'), (0, '11:30'), (0, '01:30'), (0, '07:30'), (0, '05:30'), (0, '11:00'), (0, '12:30'), (0, '19:30')]
# number of available agents 7
# observation_space is: 1
# reward is: 0
# number of available agents 2
# observation_space is: 2
# reward is: 0
# number of available agents 1
# observation_space is: 3
# reward is: 0
# number of available agents 0
# observation_space is: 4
# reward is: -660
# shifts:  [(4, '19:00'), (5, '02:30'), (1, '04:00'), (1, '02:00')]
# number of available agents 0
# observation_space is: 4
# reward is: -660
# shifts:  [(4, '19:00'), (5, '02:30'), (1, '04:00'), (1, '02:00'), (0, '07:30')]
# number of available agents 0
# observation_space is: 4
# reward is: -660
# shifts:  [(4, '19:00'), (5, '02:30'), (1, '04:00'), (1, '02:00'), (0, '07:30'), (0, '20:30')]
# number of available agents 0
# observation_space is: 4
# reward is: -660
# shifts:  [(4, '19:00'), (5, '02:30'), (1, '04:00'), (1, '02:00'), (0, '07:30'), (0, '20:30'), (0, '19:00')]
# number of available agents 0
# observation_space is: 4
# reward is: -660
# shifts:  [(4, '19:00'), (5, '02:30'), (1, '04:00'), (1, '02:00'), (0, '07:30'), (0, '20:30'), (0, '19:00'), (0, '09:30')]
# number of available agents 0
# observation_space is: 4
# reward is: -660
# shifts:  [(4, '19:00'), (5, '02:30'), (1, '04:00'), (1, '02:00'), (0, '07:30'), (0, '20:30'), (0, '19:00'), (0, '09:30'), (0, '20:30')]
# number of available agents 0
# observation_space is: 4
# reward is: -660
# shifts:  [(4, '19:00'), (5, '02:30'), (1, '04:00'), (1, '02:00'), (0, '07:30'), (0, '20:30'), (0, '19:00'), (0, '09:30'), (0, '20:30'), (0, '22:30')]
# number of available agents 0
# observation_space is: 4
# reward is: -660
# shifts:  [(4, '19:00'), (5, '02:30'), (1, '04:00'), (1, '02:00'), (0, '07:30'), (0, '20:30'), (0, '19:00'), (0, '09:30'), (0, '20:30'), (0, '22:30'), (0, '12:00')]
# number of available agents 3
# observation_space is: 1
# reward is: 0
# number of available agents 2
# observation_space is: 2
# reward is: 0
# number of available agents 1
# observation_space is: 3
# reward is: 0
# number of available agents 0
# observation_space is: 4
# reward is: -960
# shifts:  [(8, '17:00'), (1, '17:00'), (1, '20:30'), (1, '03:00')]
# number of available agents 0
# observation_space is: 4
# reward is: -960
# shifts:  [(8, '17:00'), (1, '17:00'), (1, '20:30'), (1, '03:00'), (0, '06:00')]
# number of available agents 0
# observation_space is: 4
# reward is: -960
# shifts:  [(8, '17:00'), (1, '17:00'), (1, '20:30'), (1, '03:00'), (0, '06:00'), (0, '01:00')]
# number of available agents 0
# observation_space is: 4
# reward is: -960
# shifts:  [(8, '17:00'), (1, '17:00'), (1, '20:30'), (1, '03:00'), (0, '06:00'), (0, '01:00'), (0, '20:00')]
# number of available agents 0
# observation_space is: 4
# reward is: -960
# shifts:  [(8, '17:00'), (1, '17:00'), (1, '20:30'), (1, '03:00'), (0, '06:00'), (0, '01:00'), (0, '20:00'), (0, '17:30')]
# number of available agents 0
# observation_space is: 4
# reward is: -960
# shifts:  [(8, '17:00'), (1, '17:00'), (1, '20:30'), (1, '03:00'), (0, '06:00'), (0, '01:00'), (0, '20:00'), (0, '17:30'), (0, '17:30')]
# number of available agents 0
# observation_space is: 4
# reward is: -960
# shifts:  [(8, '17:00'), (1, '17:00'), (1, '20:30'), (1, '03:00'), (0, '06:00'), (0, '01:00'), (0, '20:00'), (0, '17:30'), (0, '17:30'), (0, '19:30')]
# number of available agents 0
# observation_space is: 4
# reward is: -960
# shifts:  [(8, '17:00'), (1, '17:00'), (1, '20:30'), (1, '03:00'), (0, '06:00'), (0, '01:00'), (0, '20:00'), (0, '17:30'), (0, '17:30'), (0, '19:30'), (0, '11:30')]
# number of available agents 6
# observation_space is: 1
# reward is: 0
# number of available agents 1
# observation_space is: 2
# reward is: 0
# number of available agents 0
# observation_space is: 3
# reward is: 0
# number of available agents 0
# observation_space is: 4
# reward is: -900
# shifts:  [(5, '03:00'), (5, '02:00'), (1, '20:30'), (0, '07:00')]
# number of available agents 0
# observation_space is: 4
# reward is: -900
# shifts:  [(5, '03:00'), (5, '02:00'), (1, '20:30'), (0, '07:00'), (0, '01:00')]
# number of available agents 0
# observation_space is: 4
# reward is: -900
# shifts:  [(5, '03:00'), (5, '02:00'), (1, '20:30'), (0, '07:00'), (0, '01:00'), (0, '04:30')]
# number of available agents 0
# observation_space is: 4
# reward is: -900
# shifts:  [(5, '03:00'), (5, '02:00'), (1, '20:30'), (0, '07:00'), (0, '01:00'), (0, '04:30'), (0, '16:30')]
# number of available agents 0
# observation_space is: 4
# reward is: -900
# shifts:  [(5, '03:00'), (5, '02:00'), (1, '20:30'), (0, '07:00'), (0, '01:00'), (0, '04:30'), (0, '16:30'), (0, '23:00')]
# number of available agents 0
# observation_space is: 4
# reward is: -900
# shifts:  [(5, '03:00'), (5, '02:00'), (1, '20:30'), (0, '07:00'), (0, '01:00'), (0, '04:30'), (0, '16:30'), (0, '23:00'), (0, '18:30')]
# number of available agents 0
# observation_space is: 4
# reward is: -900
# shifts:  [(5, '03:00'), (5, '02:00'), (1, '20:30'), (0, '07:00'), (0, '01:00'), (0, '04:30'), (0, '16:30'), (0, '23:00'), (0, '18:30'), (0, '02:00')]
# number of available agents 0
# observation_space is: 4
# reward is: -900
# shifts:  [(5, '03:00'), (5, '02:00'), (1, '20:30'), (0, '07:00'), (0, '01:00'), (0, '04:30'), (0, '16:30'), (0, '23:00'), (0, '18:30'), (0, '02:00'), (0, '01:30')]
# number of available agents 8
# observation_space is: 1
# reward is: 0
# number of available agents 2
# observation_space is: 2
# reward is: 0
# number of available agents 1
# observation_space is: 3
# reward is: 0
# number of available agents 0
# observation_space is: 4
# reward is: -600
# shifts:  [(3, '15:30'), (6, '11:00'), (1, '08:30'), (1, '02:30')]
# number of available agents 0
# observation_space is: 4
# reward is: -600
# shifts:  [(3, '15:30'), (6, '11:00'), (1, '08:30'), (1, '02:30'), (0, '04:30')]
# number of available agents 0
# observation_space is: 4
# reward is: -600
# shifts:  [(3, '15:30'), (6, '11:00'), (1, '08:30'), (1, '02:30'), (0, '04:30'), (0, '04:30')]
# number of available agents 0
# observation_space is: 4
# reward is: -600
# shifts:  [(3, '15:30'), (6, '11:00'), (1, '08:30'), (1, '02:30'), (0, '04:30'), (0, '04:30'), (0, '19:00')]
# number of available agents 0
# observation_space is: 4
# reward is: -600
# shifts:  [(3, '15:30'), (6, '11:00'), (1, '08:30'), (1, '02:30'), (0, '04:30'), (0, '04:30'), (0, '19:00'), (0, '01:30')]
# number of available agents 0
# observation_space is: 4
# reward is: -600
# shifts:  [(3, '15:30'), (6, '11:00'), (1, '08:30'), (1, '02:30'), (0, '04:30'), (0, '04:30'), (0, '19:00'), (0, '01:30'), (0, '14:30')]
# number of available agents 0
# observation_space is: 4
# reward is: -600
# shifts:  [(3, '15:30'), (6, '11:00'), (1, '08:30'), (1, '02:30'), (0, '04:30'), (0, '04:30'), (0, '19:00'), (0, '01:30'), (0, '14:30'), (0, '23:00')]
# number of available agents 0
# observation_space is: 4
# reward is: -600
# shifts:  [(3, '15:30'), (6, '11:00'), (1, '08:30'), (1, '02:30'), (0, '04:30'), (0, '04:30'), (0, '19:00'), (0, '01:30'), (0, '14:30'), (0, '23:00'), (0, '19:00')]
# number of available agents 5
# observation_space is: 1
# reward is: 0
# number of available agents 4
# observation_space is: 2
# reward is: 0
# number of available agents 2
# observation_space is: 3
# reward is: 0
# number of available agents 0
# observation_space is: 4
# reward is: -540
# shifts:  [(6, '01:30'), (1, '09:00'), (2, '09:00'), (2, '07:30')]
# number of available agents 0
# observation_space is: 4
# reward is: -540
# shifts:  [(6, '01:30'), (1, '09:00'), (2, '09:00'), (2, '07:30'), (0, '09:30')]
# number of available agents 0
# observation_space is: 4
# reward is: -540
# shifts:  [(6, '01:30'), (1, '09:00'), (2, '09:00'), (2, '07:30'), (0, '09:30'), (0, '19:30')]
# number of available agents 0
# observation_space is: 4
# reward is: -540
# shifts:  [(6, '01:30'), (1, '09:00'), (2, '09:00'), (2, '07:30'), (0, '09:30'), (0, '19:30'), (0, '08:30')]
# number of available agents 0
# observation_space is: 4
# reward is: -540
# shifts:  [(6, '01:30'), (1, '09:00'), (2, '09:00'), (2, '07:30'), (0, '09:30'), (0, '19:30'), (0, '08:30'), (0, '03:00')]
# number of available agents 0
# observation_space is: 4
# reward is: -540
# shifts:  [(6, '01:30'), (1, '09:00'), (2, '09:00'), (2, '07:30'), (0, '09:30'), (0, '19:30'), (0, '08:30'), (0, '03:00'), (0, '19:30')]
# number of available agents 0
# observation_space is: 4
# reward is: -540
# shifts:  [(6, '01:30'), (1, '09:00'), (2, '09:00'), (2, '07:30'), (0, '09:30'), (0, '19:30'), (0, '08:30'), (0, '03:00'), (0, '19:30'), (0, '17:30')]
# number of available agents 0
# observation_space is: 4
# reward is: -540
# shifts:  [(6, '01:30'), (1, '09:00'), (2, '09:00'), (2, '07:30'), (0, '09:30'), (0, '19:30'), (0, '08:30'), (0, '03:00'), (0, '19:30'), (0, '17:30'), (0, '21:30')]
# number of available agents 8
# observation_space is: 1
# reward is: 0
# number of available agents 7
# observation_space is: 2
# reward is: 0
# number of available agents 0
# observation_space is: 3
# reward is: 0
# number of available agents 0
# observation_space is: 4
# reward is: -840
# shifts:  [(3, '22:30'), (1, '05:30'), (7, '20:00'), (0, '02:00')]
# number of available agents 0
# observation_space is: 4
# reward is: -840
# shifts:  [(3, '22:30'), (1, '05:30'), (7, '20:00'), (0, '02:00'), (0, '04:30')]
# number of available agents 0
# observation_space is: 4
# reward is: -840
# shifts:  [(3, '22:30'), (1, '05:30'), (7, '20:00'), (0, '02:00'), (0, '04:30'), (0, '20:30')]
# number of available agents 0
# observation_space is: 4
# reward is: -840
# shifts:  [(3, '22:30'), (1, '05:30'), (7, '20:00'), (0, '02:00'), (0, '04:30'), (0, '20:30'), (0, '05:00')]
# number of available agents 0
# observation_space is: 4
# reward is: -840
# shifts:  [(3, '22:30'), (1, '05:30'), (7, '20:00'), (0, '02:00'), (0, '04:30'), (0, '20:30'), (0, '05:00'), (0, '05:30')]
# number of available agents 0
# observation_space is: 4
# reward is: -840
# ...
# shifts:  [(1, '17:00'), (2, '04:30'), (7, '04:00'), (1, '16:00'), (0, '18:00'), (0, '15:30'), (0, '01:30')]
# number of available agents 0
# observation_space is: 4
# reward is: -660
# shifts:  [(1, '17:00'), (2, '04:30'), (7, '04:00'), (1, '16:00'), (0, '18:00'), (0, '15:30'), (0, '01:30'), (0, '06:30')]
# number of available agents 0
# observation_space is: 4
# reward is: -660
# shifts:  [(1, '17:00'), (2, '04:30'), (7, '04:00'), (1, '16:00'), (0, '18:00'), (0, '15:30'), (0, '01:30'), (0, '06:30'), (0, '05:30')]
# number of available agents 0
# observation_space is: 4
# reward is: -660
# shifts:  [(1, '17:00'), (2, '04:30'), (7, '04:00'), (1, '16:00'), (0, '18:00'), (0, '15:30'), (0, '01:30'), (0, '06:30'), (0, '05:30'), (0, '09:30')]
# number of available agents 0
# observation_space is: 4
# reward is: -660
# shifts:  [(1, '17:00'), (2, '04:30'), (7, '04:00'), (1, '16:00'), (0, '18:00'), (0, '15:30'), (0, '01:30'), (0, '06:30'), (0, '05:30'), (0, '09:30'), (0, '12:30')]
# number of available agents 7
# observation_space is: 1
# reward is: 0
# number of available agents 1
# observation_space is: 2
# reward is: 0
# number of available agents 0
# observation_space is: 3
# reward is: 0
# number of available agents 0
# observation_space is: 4
# reward is: -660
# shifts:  [(4, '15:00'), (6, '06:30'), (1, '21:00'), (0, '00:30')]
# number of available agents 0
# observation_space is: 4
# reward is: -660
# shifts:  [(4, '15:00'), (6, '06:30'), (1, '21:00'), (0, '00:30'), (0, '20:30')]
# number of available agents 0
# observation_space is: 4
# reward is: -660
# shifts:  [(4, '15:00'), (6, '06:30'), (1, '21:00'), (0, '00:30'), (0, '20:30'), (0, '04:00')]
# number of available agents 0
# observation_space is: 4
# reward is: -660
# shifts:  [(4, '15:00'), (6, '06:30'), (1, '21:00'), (0, '00:30'), (0, '20:30'), (0, '04:00'), (0, '23:30')]
# number of available agents 0
# observation_space is: 4
# reward is: -660
# shifts:  [(4, '15:00'), (6, '06:30'), (1, '21:00'), (0, '00:30'), (0, '20:30'), (0, '04:00'), (0, '23:30'), (0, '11:00')]
# number of available agents 0
# observation_space is: 4
# reward is: -660
# shifts:  [(4, '15:00'), (6, '06:30'), (1, '21:00'), (0, '00:30'), (0, '20:30'), (0, '04:00'), (0, '23:30'), (0, '11:00'), (0, '18:00')]
# number of available agents 0
# observation_space is: 4
# reward is: -660
# shifts:  [(4, '15:00'), (6, '06:30'), (1, '21:00'), (0, '00:30'), (0, '20:30'), (0, '04:00'), (0, '23:30'), (0, '11:00'), (0, '18:00'), (0, '14:30')]
# number of available agents 0
# observation_space is: 4
# reward is: -660
# shifts:  [(4, '15:00'), (6, '06:30'), (1, '21:00'), (0, '00:30'), (0, '20:30'), (0, '04:00'), (0, '23:30'), (0, '11:00'), (0, '18:00'), (0, '14:30'), (0, '02:00')]
# number of available agents 8
# observation_space is: 1
# reward is: 0
# number of available agents 1
# observation_space is: 2
# reward is: 0
# number of available agents 0
# observation_space is: 3
# reward is: 0
# number of available agents 0
# observation_space is: 4
# reward is: -720
# shifts:  [(3, '09:00'), (7, '14:00'), (1, '02:00'), (0, '22:00')]
# number of available agents 0
# observation_space is: 4
# reward is: -720
# shifts:  [(3, '09:00'), (7, '14:00'), (1, '02:00'), (0, '22:00'), (0, '11:30')]
# number of available agents 0
# observation_space is: 4
# reward is: -720
# shifts:  [(3, '09:00'), (7, '14:00'), (1, '02:00'), (0, '22:00'), (0, '11:30'), (0, '18:30')]
# number of available agents 0
# observation_space is: 4
# reward is: -720
# shifts:  [(3, '09:00'), (7, '14:00'), (1, '02:00'), (0, '22:00'), (0, '11:30'), (0, '18:30'), (0, '21:30')]
# number of available agents 0
# observation_space is: 4
# reward is: -720
# shifts:  [(3, '09:00'), (7, '14:00'), (1, '02:00'), (0, '22:00'), (0, '11:30'), (0, '18:30'), (0, '21:30'), (0, '12:30')]
# number of available agents 0
# observation_space is: 4
# reward is: -720
# shifts:  [(3, '09:00'), (7, '14:00'), (1, '02:00'), (0, '22:00'), (0, '11:30'), (0, '18:30'), (0, '21:30'), (0, '12:30'), (0, '19:00')]
# number of available agents 0
# observation_space is: 4
# reward is: -720
# shifts:  [(3, '09:00'), (7, '14:00'), (1, '02:00'), (0, '22:00'), (0, '11:30'), (0, '18:30'), (0, '21:30'), (0, '12:30'), (0, '19:00'), (0, '02:00')]
# number of available agents 0
# observation_space is: 4
# reward is: -720
# shifts:  [(3, '09:00'), (7, '14:00'), (1, '02:00'), (0, '22:00'), (0, '11:30'), (0, '18:30'), (0, '21:30'), (0, '12:30'), (0, '19:00'), (0, '02:00'), (0, '04:30')]
# number of available agents 4
# observation_space is: 1
# reward is: 0
# number of available agents 3
# observation_space is: 2
# reward is: 0
# number of available agents 1
# observation_space is: 3
# reward is: 0
# number of available agents 0
# observation_space is: 4
# reward is: -600
# shifts:  [(7, '13:00'), (1, '21:00'), (2, '02:30'), (1, '00:30')]
# number of available agents 0
# observation_space is: 4
# reward is: -600
# shifts:  [(7, '13:00'), (1, '21:00'), (2, '02:30'), (1, '00:30'), (0, '21:00')]
# number of available agents 0
# observation_space is: 4
# reward is: -600
# shifts:  [(7, '13:00'), (1, '21:00'), (2, '02:30'), (1, '00:30'), (0, '21:00'), (0, '14:00')]
# number of available agents 0
# observation_space is: 4
# reward is: -600
# shifts:  [(7, '13:00'), (1, '21:00'), (2, '02:30'), (1, '00:30'), (0, '21:00'), (0, '14:00'), (0, '20:00')]
# number of available agents 0
# observation_space is: 4
# reward is: -600
# shifts:  [(7, '13:00'), (1, '21:00'), (2, '02:30'), (1, '00:30'), (0, '21:00'), (0, '14:00'), (0, '20:00'), (0, '03:00')]
# number of available agents 0
# observation_space is: 4
# reward is: -600
# shifts:  [(7, '13:00'), (1, '21:00'), (2, '02:30'), (1, '00:30'), (0, '21:00'), (0, '14:00'), (0, '20:00'), (0, '03:00'), (0, '13:30')]
# number of available agents 0
# observation_space is: 4
# reward is: -600
# shifts:  [(7, '13:00'), (1, '21:00'), (2, '02:30'), (1, '00:30'), (0, '21:00'), (0, '14:00'), (0, '20:00'), (0, '03:00'), (0, '13:30'), (0, '12:30')]
# number of available agents 0
# observation_space is: 4
# reward is: -600
# shifts:  [(7, '13:00'), (1, '21:00'), (2, '02:30'), (1, '00:30'), (0, '21:00'), (0, '14:00'), (0, '20:00'), (0, '03:00'), (0, '13:30'), (0, '12:30'), (0, '17:30')]
# number of available agents 1
# observation_space is: 1
# reward is: 0
# number of available agents 0
# observation_space is: 2
# reward is: 0
# number of available agents 0
# observation_space is: 3
# reward is: 0
# number of available agents 0
# observation_space is: 4
# reward is: -960
# shifts:  [(10, '16:30'), (1, '00:30'), (0, '06:00'), (0, '07:00')]
# number of available agents 0
# observation_space is: 4
# reward is: -960
# shifts:  [(10, '16:30'), (1, '00:30'), (0, '06:00'), (0, '07:00'), (0, '22:00')]
# number of available agents 0
# observation_space is: 4
# reward is: -960
# shifts:  [(10, '16:30'), (1, '00:30'), (0, '06:00'), (0, '07:00'), (0, '22:00'), (0, '20:00')]
# number of available agents 0
# observation_space is: 4
# reward is: -960
# shifts:  [(10, '16:30'), (1, '00:30'), (0, '06:00'), (0, '07:00'), (0, '22:00'), (0, '20:00'), (0, '12:00')]
# number of available agents 0
# observation_space is: 4
# reward is: -960
# shifts:  [(10, '16:30'), (1, '00:30'), (0, '06:00'), (0, '07:00'), (0, '22:00'), (0, '20:00'), (0, '12:00'), (0, '10:00')]
# number of available agents 0
# observation_space is: 4
# reward is: -960
# shifts:  [(10, '16:30'), (1, '00:30'), (0, '06:00'), (0, '07:00'), (0, '22:00'), (0, '20:00'), (0, '12:00'), (0, '10:00'), (0, '19:00')]
# number of available agents 0
# observation_space is: 4
# reward is: -960
# shifts:  [(10, '16:30'), (1, '00:30'), (0, '06:00'), (0, '07:00'), (0, '22:00'), (0, '20:00'), (0, '12:00'), (0, '10:00'), (0, '19:00'), (0, '19:00')]
# number of available agents 0
# observation_space is: 4
# reward is: -960
# shifts:  [(10, '16:30'), (1, '00:30'), (0, '06:00'), (0, '07:00'), (0, '22:00'), (0, '20:00'), (0, '12:00'), (0, '10:00'), (0, '19:00'), (0, '19:00'), (0, '18:00')]
# number of available agents 5
# observation_space is: 1
# reward is: 0
# number of available agents 0
# observation_space is: 2
# reward is: 0
# number of available agents 0
# observation_space is: 3
# reward is: 0
# number of available agents 0
# observation_space is: 4
# reward is: -720
# shifts:  [(6, '20:30'), (5, '11:00'), (0, '04:30'), (0, '08:30')]
# number of available agents 0
# observation_space is: 4
# reward is: -720
# shifts:  [(6, '20:30'), (5, '11:00'), (0, '04:30'), (0, '08:30'), (0, '17:30')]
# number of available agents 0
# observation_space is: 4
# reward is: -720
# shifts:  [(6, '20:30'), (5, '11:00'), (0, '04:30'), (0, '08:30'), (0, '17:30'), (0, '20:00')]
# number of available agents 0
# observation_space is: 4
# reward is: -720
# shifts:  [(6, '20:30'), (5, '11:00'), (0, '04:30'), (0, '08:30'), (0, '17:30'), (0, '20:00'), (0, '04:00')]
# number of available agents 0
# observation_space is: 4
# reward is: -720
# shifts:  [(6, '20:30'), (5, '11:00'), (0, '04:30'), (0, '08:30'), (0, '17:30'), (0, '20:00'), (0, '04:00'), (0, '09:30')]
# number of available agents 0
# observation_space is: 4
# reward is: -720
# shifts:  [(6, '20:30'), (5, '11:00'), (0, '04:30'), (0, '08:30'), (0, '17:30'), (0, '20:00'), (0, '04:00'), (0, '09:30'), (0, '02:00')]
# number of available agents 0
# observation_space is: 4
# reward is: -720
# shifts:  [(6, '20:30'), (5, '11:00'), (0, '04:30'), (0, '08:30'), (0, '17:30'), (0, '20:00'), (0, '04:00'), (0, '09:30'), (0, '02:00'), (0, '08:30')]
# number of available agents 0
# observation_space is: 4
# reward is: -720
# shifts:  [(6, '20:30'), (5, '11:00'), (0, '04:30'), (0, '08:30'), (0, '17:30'), (0, '20:00'), (0, '04:00'), (0, '09:30'), (0, '02:00'), (0, '08:30'), (0, '16:00')]
# number of available agents 3
# observation_space is: 1
# reward is: 0
# number of available agents 0
# observation_space is: 2
# reward is: 0
# number of available agents 0
# observation_space is: 3
# reward is: 0
# number of available agents 0
# observation_space is: 4
# reward is: -720
# shifts:  [(8, '10:30'), (3, '03:30'), (0, '09:30'), (0, '22:00')]
# number of available agents 0
# observation_space is: 4
# reward is: -720
# shifts:  [(8, '10:30'), (3, '03:30'), (0, '09:30'), (0, '22:00'), (0, '18:30')]
# number of available agents 0
# observation_space is: 4
# reward is: -720
# shifts:  [(8, '10:30'), (3, '03:30'), (0, '09:30'), (0, '22:00'), (0, '18:30'), (0, '13:30')]
# number of available agents 0
# observation_space is: 4
# reward is: -720
# shifts:  [(8, '10:30'), (3, '03:30'), (0, '09:30'), (0, '22:00'), (0, '18:30'), (0, '13:30'), (0, '17:30')]
# number of available agents 0
# observation_space is: 4
# reward is: -720
# shifts:  [(8, '10:30'), (3, '03:30'), (0, '09:30'), (0, '22:00'), (0, '18:30'), (0, '13:30'), (0, '17:30'), (0, '10:30')]
# number of available agents 0
# observation_space is: 4
# reward is: -720
# shifts:  [(8, '10:30'), (3, '03:30'), (0, '09:30'), (0, '22:00'), (0, '18:30'), (0, '13:30'), (0, '17:30'), (0, '10:30'), (0, '05:30')]
# number of available agents 0
# observation_space is: 4
# reward is: -720
# shifts:  [(8, '10:30'), (3, '03:30'), (0, '09:30'), (0, '22:00'), (0, '18:30'), (0, '13:30'), (0, '17:30'), (0, '10:30'), (0, '05:30'), (0, '03:00')]
# number of available agents 0
# observation_space is: 4
# reward is: -720
# shifts:  [(8, '10:30'), (3, '03:30'), (0, '09:30'), (0, '22:00'), (0, '18:30'), (0, '13:30'), (0, '17:30'), (0, '10:30'), (0, '05:30'), (0, '03:00'), (0, '21:30')]
# number of available agents 2
# observation_space is: 1
# reward is: 0
# number of available agents 1
# observation_space is: 2
# reward is: 0
# number of available agents 0
# observation_space is: 3
# reward is: 0
# number of available agents 0
# observation_space is: 4
# reward is: -720
# shifts:  [(9, '13:30'), (1, '15:30'), (1, '17:00'), (0, '16:30')]
# number of available agents 0
# observation_space is: 4
# reward is: -720
# shifts:  [(9, '13:30'), (1, '15:30'), (1, '17:00'), (0, '16:30'), (0, '10:00')]
# number of available agents 0
# observation_space is: 4
# reward is: -720
# shifts:  [(9, '13:30'), (1, '15:30'), (1, '17:00'), (0, '16:30'), (0, '10:00'), (0, '13:00')]
# number of available agents 0
# observation_space is: 4
# reward is: -720
# shifts:  [(9, '13:30'), (1, '15:30'), (1, '17:00'), (0, '16:30'), (0, '10:00'), (0, '13:00'), (0, '07:30')]
# number of available agents 0
# observation_space is: 4
# reward is: -720
# shifts:  [(9, '13:30'), (1, '15:30'), (1, '17:00'), (0, '16:30'), (0, '10:00'), (0, '13:00'), (0, '07:30'), (0, '05:30')]
# number of available agents 0
# observation_space is: 4
# reward is: -720
# shifts:  [(9, '13:30'), (1, '15:30'), (1, '17:00'), (0, '16:30'), (0, '10:00'), (0, '13:00'), (0, '07:30'), (0, '05:30'), (0, '18:30')]
# number of available agents 0
# observation_space is: 4
# reward is: -720
# shifts:  [(9, '13:30'), (1, '15:30'), (1, '17:00'), (0, '16:30'), (0, '10:00'), (0, '13:00'), (0, '07:30'), (0, '05:30'), (0, '18:30'), (0, '14:30')]
# number of available agents 0
# observation_space is: 4
# reward is: -720
# shifts:  [(9, '13:30'), (1, '15:30'), (1, '17:00'), (0, '16:30'), (0, '10:00'), (0, '13:00'), (0, '07:30'), (0, '05:30'), (0, '18:30'), (0, '14:30'), (0, '09:30')]
# number of available agents 3
# observation_space is: 1
# reward is: 0
# number of available agents 1
# observation_space is: 2
# reward is: 0
# number of available agents 0
# observation_space is: 3
# reward is: 0
# number of available agents 0
# observation_space is: 4
# reward is: -540
# shifts:  [(8, '03:00'), (2, '14:30'), (1, '00:00'), (0, '08:30')]
# number of available agents 0
# observation_space is: 4
# reward is: -540
# shifts:  [(8, '03:00'), (2, '14:30'), (1, '00:00'), (0, '08:30'), (0, '02:30')]
# number of available agents 0
# observation_space is: 4
# reward is: -540
# shifts:  [(8, '03:00'), (2, '14:30'), (1, '00:00'), (0, '08:30'), (0, '02:30'), (0, '06:00')]
# number of available agents 0
# observation_space is: 4
# reward is: -540
# shifts:  [(8, '03:00'), (2, '14:30'), (1, '00:00'), (0, '08:30'), (0, '02:30'), (0, '06:00'), (0, '20:00')]
# number of available agents 0
# observation_space is: 4
# reward is: -540
# shifts:  [(8, '03:00'), (2, '14:30'), (1, '00:00'), (0, '08:30'), (0, '02:30'), (0, '06:00'), (0, '20:00'), (0, '11:00')]
# number of available agents 0
# observation_space is: 4
# reward is: -540
# shifts:  [(8, '03:00'), (2, '14:30'), (1, '00:00'), (0, '08:30'), (0, '02:30'), (0, '06:00'), (0, '20:00'), (0, '11:00'), (0, '00:00')]
# number of available agents 0
# observation_space is: 4
# reward is: -540
# shifts:  [(8, '03:00'), (2, '14:30'), (1, '00:00'), (0, '08:30'), (0, '02:30'), (0, '06:00'), (0, '20:00'), (0, '11:00'), (0, '00:00'), (0, '15:00')]
# number of available agents 0
# observation_space is: 4
# reward is: -540
# shifts:  [(8, '03:00'), (2, '14:30'), (1, '00:00'), (0, '08:30'), (0, '02:30'), (0, '06:00'), (0, '20:00'), (0, '11:00'), (0, '00:00'), (0, '15:00'), (0, '20:00')]
# number of available agents 7
# observation_space is: 1
# reward is: 0
# number of available agents 3
# observation_space is: 2
# reward is: 0
# number of available agents 1
# observation_space is: 3
# reward is: 0
# number of available agents 0
# observation_space is: 4
# reward is: -360
# shifts:  [(4, '15:30'), (4, '18:30'), (2, '06:00'), (1, '20:00')]
# number of available agents 0
# observation_space is: 4
# reward is: -360
# shifts:  [(4, '15:30'), (4, '18:30'), (2, '06:00'), (1, '20:00'), (0, '08:00')]
# number of available agents 0
# observation_space is: 4
# reward is: -360
# shifts:  [(4, '15:30'), (4, '18:30'), (2, '06:00'), (1, '20:00'), (0, '08:00'), (0, '18:30')]
# number of available agents 0
# observation_space is: 4
# reward is: -360
# shifts:  [(4, '15:30'), (4, '18:30'), (2, '06:00'), (1, '20:00'), (0, '08:00'), (0, '18:30'), (0, '13:00')]
# number of available agents 0
# observation_space is: 4
# reward is: -360
# shifts:  [(4, '15:30'), (4, '18:30'), (2, '06:00'), (1, '20:00'), (0, '08:00'), (0, '18:30'), (0, '13:00'), (0, '14:00')]
# number of available agents 0
# observation_space is: 4
# reward is: -360
# shifts:  [(4, '15:30'), (4, '18:30'), (2, '06:00'), (1, '20:00'), (0, '08:00'), (0, '18:30'), (0, '13:00'), (0, '14:00'), (0, '15:30')]
# number of available agents 0
# observation_space is: 4
# reward is: -360
# shifts:  [(4, '15:30'), (4, '18:30'), (2, '06:00'), (1, '20:00'), (0, '08:00'), (0, '18:30'), (0, '13:00'), (0, '14:00'), (0, '15:30'), (0, '16:00')]
# number of available agents 0
# observation_space is: 4
# reward is: -360
# shifts:  [(4, '15:30'), (4, '18:30'), (2, '06:00'), (1, '20:00'), (0, '08:00'), (0, '18:30'), (0, '13:00'), (0, '14:00'), (0, '15:30'), (0, '16:00'), (0, '19:30')]

# %%
import matplotlib.pyplot as plt

# Your data
data = calculate_shift_extended(s.gk)

# Splitting the data into two lists: one for time and one for counts
times = list(data.keys())
counts = list(data.values())

# Creating the bar chart
plt.figure(figsize=(10, 5))  # Set the figure size (optional)
plt.bar(times, counts, color='blue')
plt.xticks(rotation=90)  # Rotate the x-axis labels for better readability
plt.xlabel('Time')
plt.ylabel('Count')
plt.title('Counts per 30-minute interval over a 24-hour period')
plt.tight_layout()  # Adjust the layout to prevent clipping of labels
plt.plot(arrivals['arrivals'])
print("The reward at the end of the episode is: ",reward)
print("The maximum reward we could get is:",48*30)
plt.show()  # Display the chart
# Out:
# The reward at the end of the episode is:  -840
# The maximum reward we could get is: 1440

# %%
plt.plot(reward_list)

# %% [markdown]
# ### On policy control with SARSA

# %% [markdown]
# ![Sarsa.PNG](attachment:Sarsa.PNG)

# %%
# reset environement
s=scheduling(n_agents=11,n_services=1,n_shifts=4)

# %%
# initialize the Q(s,a)
Q=torch.rand((s.n_shifts*s.n_services,s.n_st,s.n_agents))
#Assuming we are at state 0
# Get the max value and its linear index
print((Q[0]==torch.max(Q[0])).nonzero())
# Out:
# tensor([[20,  3]])

# %%
# lets define an epsilon greedy policy derived from Q
